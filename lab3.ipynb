# %%
#Student Score Tracker

# %%
student_name = "Aarav"
subject = "Mathematics"
score = 95
print( student_name, "scored", score, "in", subject)
# Out:
# Aarav scored 95 in Mathematics

# %%
# Type Conversion for Billing

# %%
item = input("Enter item name: ")
quantity = int(input("Enter quantity: "))
price = float(input("Enter price per item: "))
total = quantity * price
print(f" Total cost for {item}: ₹{total}")
# Out:
# Enter item name:  wallet
# Enter quantity:  1
# Enter price per item:  120
#  Total cost for wallet: ₹120.0

# %%
# Eligibility Checker

# %%
age = int(input("Enter your age: "))
is_eligible = age >= 18
print(" Eligible to vote:", is_eligible)
# Out:
# Enter your age:  23
#  Eligible to vote: True

# %%
#Event Registration Form

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
email = input("Enter your email: ")

print(f"""
📋 Registration Summary:
Name: {name}
Age: {age}
Email: {email}
""")
