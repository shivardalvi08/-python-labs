# %%
# First Python Program

# %%
print("Hello, World!")
print("My name is Dhruv Patel.")
print("I love programming in Python!")
# Out:
# Hello, World!
# My name is Dhruv Patel.
# I love programming in Python!

# %%
# Quote Display Program

# %%
print("Keep pushing forward, one line of code at a time.")
# Out:
# Keep pushing forward, one line of code at a time.

# %%
#Fix the following incorrect code:

# %%
def greet():
print("Hello!")
 print("Welcome to Python.")

greet()
# Out:
#   Cell In[7], line 2
#     print("Hello!")
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
#Corrected Code:

# %%
def greet():
    print("Hello!")
    print("Welcome to Python.")

greet()
# Out:
# Hello!
# Welcome to Python.

# %%
# This program adds two numbers

# %%
"""
Multi-line comment:
Author: Dhruv Patel
Date: 5th July 2025
Purpose: Demonstrate comments
"""
# Out:
# '\nMulti-line comment:\nAuthor: Dhruv Patel\nDate: 5th July 2025\nPurpose: Demonstrate comments\n'

# %%
num1 = 10  # First number
num2 = 20  # Second number

# %%
# Adding the numbers

# %%
sum = num1 + num2
print("Sum:", sum)
# Out:
# Sum: 30
